# %%
# %run Functions.py
from LogCal_code import index_find

# %%
from drift.core import manager

m = manager.ProductManager.from_config('/home/zahra/PIPELINE/8by8_no_sims/prod_params_custom.yaml')
# Out:
# Product directory: /home/zahra/PIPELINE/8by8_no_sims/bt_matrices

# %%
pert_gain_rec_10cm = np.load('saved_arrays/recovered_gains_31Aug_pt1_dishscat.npy')
vis_pert_true_10cm = np.load('saved_arrays/true_visibilities_total_perturbed_10cm.npy')

pert_gain_rec_1cm = np.load('saved_arrays/recovered_gains_31Aug_pt01_dishscat.npy')
vis_pert_true_1cm = np.load('saved_arrays/true_visibilities_total_perturbed_1cm.npy')

pert_gain_rec_pt5cm = np.load('saved_arrays/recovered_gains_31Aug_pt5cm_dishscat.npy')
vis_pert_true_pt5cm = np.load('saved_arrays/true_visibilities_total_perturbed_pt5cm.npy')

unpert_gain_rec = np.load('saved_arrays/recovered_gains_31Aug_no_dishscat.npy')
vis_unpert_true = np.load('saved_arrays/true_visibilities_total_unperturbed.npy')

# %%
visibilities_unperturbed = np.load('saved_arrays/true_visibilities_total_unperturbed.npy')

# %%
Get_median_and_range(m, true_vis_pert=vis_pert_true_10cm, pert_level=10, median_colour='k', range_colour='g',Calibration_error=True, pert_gain_rec=pert_gain_rec_10cm, true_vis_unpert=None, length=True, savefig=False,fig_name=None)
Get_median_and_range(m,true_vis_pert=vis_pert_true_1cm, pert_level=1, median_colour='b', range_colour='r',Calibration_error=True, pert_gain_rec=pert_gain_rec_1cm, true_vis_unpert=None, length=True, savefig=False,fig_name=None)
Get_median_and_range(m,true_vis_pert=vis_pert_true_pt5cm, pert_level=0.5, median_colour='m', range_colour='y',Calibration_error=True, pert_gain_rec=pert_gain_rec_pt5cm, true_vis_unpert=None, length=True, savefig=False,fig_name=None)
# Out:
# 0.005262915558326406
# 0.0025701686151902623
# 0.0016443217406009764

# %%
Get_median_and_range(m, true_vis_pert=vis_pert_true_10cm, pert_level=10, median_colour='k', range_colour='g',Calibration_error=False, pert_gain_rec=None, true_vis_unpert=visibilities_unperturbed, length=True, savefig=False,fig_name=None)
Get_median_and_range(m, true_vis_pert=vis_pert_true_1cm, pert_level=1, median_colour='b', range_colour='r',Calibration_error=False, pert_gain_rec=None, true_vis_unpert=visibilities_unperturbed, length=True, savefig=False,fig_name=None)
Get_median_and_range(m, true_vis_pert=vis_pert_true_pt5cm, pert_level=0.5, median_colour='m', range_colour='y',Calibration_error=False, pert_gain_rec=None, true_vis_unpert=visibilities_unperturbed, length=True, savefig=False,fig_name=None)
# Out:
# 0.4055221885151131
# 0.03965426752610395
# 0.007912903719147987
